# %% [markdown]
# #### clover api (OCR)

# %% [markdown]
# * google api 계정 생성 방법 (https://www.youtube.com/watch?v=hkKKfEqZvn4)

# %% [markdown]
# * 실행하기 전 poppler 다운로드 (https://github.com/oschwartz10612/poppler-windows/releases)
# * 해당경로에 압축해제 (C:\)

# %%
from google.cloud import documentai
import os
import json
import io
from PyPDF2 import PdfReader, PdfWriter

# 서비스 계정 키 파일 경로 설정
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\ocr_google_api_key.json"

def split_pdf(input_pdf_path):
    output_path = r"C:\Users\User\spring_web\eduSmileson\ai_models\pdf2json"
    """PDF 파일을 15페이지씩 분할"""
    reader = PdfReader(input_pdf_path)
    total_pages = len(reader.pages)

    os.makedirs(output_path, exist_ok=True)

    split_files = []
    for i in range(0, total_pages, 15):
        writer = PdfWriter()
        for j in range(i, min(i + 15, total_pages)):
            writer.add_page(reader.pages[j])

        split_file_path = os.path.join(output_path, f"split_{i // 15 + 1}.pdf")
        with open(split_file_path, "wb") as output_pdf:
            writer.write(output_pdf)
        split_files.append(split_file_path)

    return split_files

def extract_text_from_pdf(pdf_path):
    project_id = "core-appliance-448400-j0"  # GCP 프로젝트 ID
    location = "us"  # Document AI 위치
    processor_id = "88019ccdcd45082a"  # 프로세서 ID

    client = documentai.DocumentProcessorServiceClient()
    name = f"projects/{project_id}/locations/{location}/processors/{processor_id}"

    with open(pdf_path, "rb") as file:
        pdf = file.read()

    document = {"content": pdf, "mime_type": "application/pdf"}  # PDF 파일
    request = {"name": name, "raw_document": document}

    response = client.process_document(request=request)

    extracted_data = {
        "text": response.document.text,
        "entities": [
            {"type": entity.type_, "value": entity.mention_text}
            for entity in response.document.entities
        ],
    }

    return extracted_data

def process_large_pdf(input_pdf_path):
    output_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json"
    """큰 PDF를 분할 처리하고 결과 병합"""
    split_dir = os.path.join(output_path, "split_pdfs")
    os.makedirs(output_path, exist_ok=True)

    # PDF를 분할
    split_files = split_pdf(input_pdf_path)

    # 분할된 PDF 처리
    merged_text = ""
    merged_entities = []
    for split_file in split_files:
        extracted_data = extract_text_from_pdf(split_file)
        merged_text += extracted_data["text"] + "\n"
        merged_entities.extend(extracted_data["entities"])

    # 최종 병합 데이터 저장
    final_data = {
        "text": merged_text,
        "entities": merged_entities,
    }
    output_file = os.path.join(output_path, "final_extracted_data.json")
    with open(output_file, "w", encoding="utf-8") as json_file:
        json.dump(final_data, json_file, ensure_ascii=False, indent=4)

    print(f"모든 데이터를 병합하여 저장했습니다: {output_file}")
    return final_data["text"]

# GCP 프로젝트 정보
pdf_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\생기부.pdf"  # PDF 파일 경로

# 함수 호출
process_large_pdf(pdf_path)
# Out:
# 모든 데이터를 병합하여 저장했습니다: C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json\final_extracted_data.json
# "문서확인번호: 1737-3485-7200-3304 (신청인: 김강용)\n학교생활세부사항기록부(학교생활기록부 I\n졸업 대장 번호 3135\n구분\n학년\n1\n2\n3\n1. 인적사항\n학과\n반 번호\n담임성명\n5\n4\n양상희\n7\n3\n최지원\n8\n6\n이준영\n성명 : 김강용\n학생\n성별: 남\n주민등록번호: 990611-***인들은 일들은 일들은 인물을\n주소:충청북도 청주시 흥덕구 덕암로6번길 42, 2815 (봉명동)\n가족 부\n성명:\n생년월일:\n상황 모\n성명:\n생년월일 :\n특기사항\n2. 학적사항\n2015년 2월 11일 송절중학교 제3학년 졸업\n2015년 3월 2일 봉명고등학교 제1학년 입학\n2018년 2월 8일 봉명고등학교 제3학년 졸업\n특기사항\n3. 출결상황\n람\n용\n학년 수업일수\n결석일수\n지각\n조퇴\n결과\n특기사항\n질병 무단 기타 질병 무단 기타 질병 무단 기타 질병 무단 기타\n| 1 | 182 | ::: 개관 -\n봉명고등학교\n2025년 1월 20일 1/19 [반] 8 번호 6| 이름 김강용\n※본 증명서는 열람용이며, 법적 효력이 없습니다.\n문서확인번호: 1737-3485-7200-3304 (신청인: 김강용)\n학년 수업일수\n3\n결석일수\n지각\n조퇴\n결과\n질병 무단 기타 질병 무단 기타 질병 무단 기타 질병 무단 기타\n192...5.......\n특기사항\n4. 수상경력\n구분\n수상명\n등급(위)\n수상연월일\n수여기관\n참가대상(참가인원)\n교내상\n2015학년도 신입생 과\n제물\n최우수(1위)\n2015.03.16.\n봉명고등학교장\n1학년(311명)\n근면상(3년정근)\n2018.02.08.\n봉명고등학교장\n3학년 (321명)\n5. 자격증 및 인증 취득상황\n<자격증 및 인증 취득상황>\n구분\n명칭 또는 종류\n학년\n학기\n세분류\n번호 또는 내용\n해당 사항 없음\n능력단위\n(능력단위코드)\n취득연월일\n발급기관\n이수시간\n원점수\n성취도\n비고\n해당 사항 없음\n6. 진로희망사항\n진로희망\n학년\n특기 또는 흥미\n학생\n학부모\n요\n희망사유\n1\n수학 관련 잡지 읽기\n통계청 공무원\n교내 전문 직업인 특강에서 통계청 공무원을 만\n나 강의를 듣고 나서 흥미를 느끼게 됨. 관련\n행정직 공무원 도서를 찾아보고 진로탐색 활동에 참여하여 해\n당 직업의 특성을 알게 된 후 확실한 진로로 설\n정함.\n평소 수학에 관심과 흥미가 있었고 직업특강 시\n간에 통계청 공무원분들께서 국민들을 대상으\n2 바둑, 수학(통계)\n통계청 공무원통계청 공무원로 유용한 정보들을 통계라는 수학적 도구로 제\n|공한다라는 사실에 감명을 받아 통계청 공무원\n을 희망진로로 설정함.\n3\n볼링, 수학 게임\n통계에 관해 관심이 많아 다양한 통계에 대해\n보험 계리사 통계청 공무원 조사하던 중 보험 통계에 대해 알고 큰 흥미를\n느껴 보험 분야의 진로를 생각해보던 중 보험\n봉명고등학교\n2025년 1월 20일 2/19 반 8 | 번호 6| 이름 김강용\n※본 증명서는 열람용이며, 법적 효력이 없습니다.\n문서확인번호: 1737-3485-7200-3304 (신청인: 김강용)\n진로희망\n학년\n특기 또는 흥미\n희망사유\n학생\n학부모\n계리사를 알게 되었고 그 직업에 큰 매력을 느\n낌.\n7. 창의적 체험활동상황\n창의적체험활 동 상 황\n학년\n영역\n시간\n특기사항\n1\n자율활동\n78\n국토순례문화답사(2015.03.24.-2015.03.27.)에 참여함. '전란의 아픔\n과 상처를 딛고서'라는 주제로 전라도 임실, 남원, 해남, 거제 등지를 방문\n하고 관련 체험 활동을 실시함. 답사후 기행문, 융합과제물 작성 및 발표\n에 적극 참여하여 성과를 냄.\n체육대회(2015.05.14.-2015.05.15.)경기 및 학급 응원에 적극 참여함.\n줄다리기, 단체줄넘기, 축구 대표 선수로 참여함. 뛰어난 협동심과 끈기\n를 보임.\n덤박골 축제 (2015.08.17.)에 적극 참여함. 창의융합수학 동아리 부스를\n설치하고 운영하여 호응을 얻음. 프렉탈 구조를 이용한 열쇠고리를 제작\n하고 전시, 설명하는 활동을 함. 행사후 뒷정리에 솔선하여 책임감 있는\n모습을 보임.\nEnglish Festival(2015.12.18.)에 참여함. 학급 전체가 참여하는 ENG\n[LISH MUSIC CONTEST에서 가창과 안무를 계획하여 연습함. 연습과\n발표에 성실하게 참여하여 책임감과 적극성을 발휘함. 영어 Golden Bell\n에서는 영어권 문화에 대한 문제를 풀어 좋은 결과를 얻음.\n금연, 금주, 약물오남용 교육 (2015.05.07.), 심폐소생술 교육 (2015.05.\n|28.), 인터넷중독 예방교육(2015. 11. 30.), 생명존중 특강(2015. 12. 10.)\n등 교내에서 진행한 외부강사 초청 교육에 빠짐 없이 참여함.\n(창의융합수학반) (53시간) 켄켄퍼즐, 착시, 종이접어 한 번에 자르기(대\n칭), 매직카드, 프랙탈, 시에르핀스키 삼각형, 전략게임, 트러스아치구조,\n보드게임(SET, 결합게임) 등 다양한 수학을 접하며 수학에 대한 흥미를\n키움. 이러한 활동을 바탕으로 제9회 덤박골축제 (2015.08.17.)에서 4D\n프레임으로 핸드폰줄 만들기(시에르핀스키 삼각형, 오더리 삼각형)를 주\n제로 체험 부스를 운영함. 자신의 진로와 수학이 어떻게 연관될 수 있는지\n고민하고 정보를 검색하여 정리함.\n(한국해양소년단충북연맹 : 청소년단체) 청주야구장을 방문(2015.07.1\n6.)하여 활기차고 적극적으로 응원하였으며 경기 관람 후 야구장 및 인근\n지역 정화활동에 열심히 참여함. 해동이와 함께 떠나는 놀이교실 (2015.1\n2.12.)에 참여하여 올바른 놀이의 의미에 대해 이해하고 건강한 마음가짐\n동아리활동\n74\n봉명고등학교\n2025년 1월 20일\n3/19 [반] 8 번호 6| 이름 | 김강용\n※본 증명서는 열람용이며, 법적 효력이 없습니다.\n문서확인번호: 1737-3485-7200-3304 (신청인: 김강용)\n창의적 체험 활동상황\n학년\n영역\n시간\n을 갖게 됨.\n1\n봉사활동\n진로활동\n특기사항\n46\n46\n(봉명FC: 방과후학교스포츠클럽) (21시간)\n교내 환경정화 활동 및 캠페인활동에 적극 참여하여 성실함을 보임. 책임\n감 있게 맡은 바 임무를 수행하고 성심을 다해 봉사하는 태도가 내면화 된\n학생임.\n청주 헌혈의집 성안길센터에 주기적으로 방문하여 헌혈자 에스코트 및 안\n내 임무를 수행함. 봉사를 한번 수행하는 것이 아니라 동일한 장소에 집중\n적으로 방문하여 실질적인 봉사가 이루어질 수 있도록 함. 봉사 경험을 바\n탕으로 학교생활에 적극성을 갖게 되었으며 솔선수범하는 자세로 학교 생\n활에 임하게 됨.\n교내 아침봉사활동(2015.09.14.-2015.09.25.)에 참여함. 다른 학생보\n다 일찍 등교해서 학교 주변의 환경을 정리하고 쓰레기 분리수거장 등 취\n약지역을 돌아보는 활동임. 등교시간이 앞당겨지는 만큼 다른 학생들이\n참여하기 어려운 활동임에도 자원하고 나서서 성실하게 봉사에 참여함.\n아침마다 학교를 청소하고 환경을 정리하면서 보람을 느끼는 동시에 학교\n구성원으로서의 자부심을 느낌. 성실한 태도와 책임감으로 봉사활동 담\n당 교사와 학교 구성원들에게 많은 칭찬을 받음.\n2015학년도 1학년을 위한 2018 대입 성공 점검 포인트 강의 (2015.03.0\n15.) 를 들음. 입시 전형에 대해 이해하고 이후 학교생활의 계획을 수립함.\n문화답사와 함께하는 진로체험 활동(2015.03.24.)에 치즈마을 견학과\n치즈제조사 체험으로 참여함. 다양한 직업세계를 체험하고 견문을 넓힘.\n커리어넷에서 실시한 진로성숙도검사(2015.04.10.), 직업흥미검사(H형)\n(2015.05.08.), 직업적성검사(2015.05.29.), 직업가치관 검사(2015. 0\n6.12.)를 통해 다양한 직업 중 자신에게 적합한 직업유형을 찾아보고 스\n스로 판단해보는 작업을 함.\n선배와 함께하는 전공탐색 특강(2015. 08. 21.)에서는 수학교육과와 사회\n복지학과를 ...

# %%
import os

# 사용 예시
pdf_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\생기부.pdf"  # PDF 파일 경로
output_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json"  # 저장될 경로

try:
    extracted_text = extract_text_from_pdf(pdf_path)

        
except Exception as e:
    print(f"에러 발생: {str(e)}")
# Out:
# 에러 발생: 400 Document pages exceed the limit: 15 got 19 [reason: "PAGE_LIMIT_EXCEEDED"
# domain: "documentai.googleapis.com"
# metadata {
#   key: "pages"
#   value: "19"
# }
# metadata {
#   key: "page_limit"
#   value: "15"
# }
# ]

# %% [markdown]
# #### txt2summary (Claude)

# %%
from google.cloud import vision
import os
from pdf2image import convert_from_path
import io
from anthropic import Anthropic
from datetime import datetime
from pathlib import Path
import json
import time

class PDFProcessor:
    #기본설정
    def __init__(self, api_key_path: str, output_folder: str = "pdf2summary"):
        """PDF와 학생 정보를 처리하는 클래스"""
        self.output_folder = Path(output_folder)
        self.api_key = self._read_api_key(api_key_path)
        self.claude_client = Anthropic(api_key=self.api_key)
        self.vision_client = vision.ImageAnnotatorClient()
        self._create_folders()
        self.last_api_call = 0
        self.min_delay = 1
    # pdf를 분할하는 함수
    def split_pdf(self,input_pdf_path: str) -> str:
        output_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json"
        """PDF 파일을 15페이지씩 분할"""
        reader = PdfReader(input_pdf_path)
        total_pages = len(reader.pages)

        os.makedirs(output_path, exist_ok=True)

        split_files = []
        for i in range(0, total_pages, 15):
            writer = PdfWriter()
            for j in range(i, min(i + 15, total_pages)):
                writer.add_page(reader.pages[j])

            split_file_path = os.path.join(output_path, f"split_{i // 15 + 1}.pdf")
            with open(split_file_path, "wb") as output_pdf:
                writer.write(output_pdf)
            split_files.append(split_file_path)

        return split_files
    
    #OCR를 활용하여 pdf파일을 json파일로 저장
    def extract_text_from_pdf(self,pdf_path: str) -> str:
        project_id = "core-appliance-448400-j0"  # GCP 프로젝트 ID
        location = "us"  # Document AI 위치
        processor_id = "88019ccdcd45082a"  # 프로세서 ID

        client = documentai.DocumentProcessorServiceClient()
        name = f"projects/{project_id}/locations/{location}/processors/{processor_id}"

        with open(pdf_path, "rb") as file:
            pdf = file.read()

        document = {"content": pdf, "mime_type": "application/pdf"}  # PDF 파일
        request = {"name": name, "raw_document": document}

        response = client.process_document(request=request)

        extracted_data = {
            "text": response.document.text,
            "entities": [
                {"type": entity.type_, "value": entity.mention_text}
                for entity in response.document.entities
            ]
        }

        return extracted_data

    def process_large_pdf(self,input_pdf_path: str) -> str:
        output_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json"
        """큰 PDF를 분할 처리하고 결과 병합"""
        split_dir = os.path.join(output_path, "split_pdfs")
        os.makedirs(output_path, exist_ok=True)

        # PDF를 분할
        split_files = self.split_pdf(input_pdf_path)

        # 분할된 PDF 처리
        merged_text = ""
        merged_entities = []
        for split_file in split_files:
            extracted_data = self.extract_text_from_pdf(split_file)
            merged_text += extracted_data["text"] + "\n"
            merged_entities.extend(extracted_data["entities"])

        # 최종 병합 데이터 저장
        final_data = {
            "text": merged_text,
            "entities": merged_entities
        }
        output_file = os.path.join(output_path, "final_extracted_data.json")
        with open(output_file, "w", encoding="utf-8") as json_file:
            json.dump(final_data, json_file, ensure_ascii=False, indent=4)

        print(f"모든 데이터를 병합하여 저장했습니다: {output_file}")
        return final_data["text"]

    
    def _read_api_key(self, api_key_path: str) -> str:
        """API 키를 파일에서 읽어옵니다."""
        try:
            with open(api_key_path, 'r', encoding='utf-8') as f:
                return f.read().strip()
        except Exception as e:
            raise Exception(f"API 키 파일을 읽는 중 오류 발생: {str(e)}")

    def _create_folders(self):
        """필요한 폴더를 생성합니다."""
        self.output_folder.mkdir(parents=True, exist_ok=True)

    def _generate_filename(self, original_filename: str) -> str:
        """결과 파일명을 생성합니다."""
        date_str = datetime.now().strftime('%Y%m%d_%H%M%S')
        original_name = Path(original_filename).stem
        return f"summary_{original_name}_{date_str}"

    def _respect_rate_limit(self):
        """API 호출 간격을 조절합니다."""
        current_time = time.time()
        time_since_last_call = current_time - self.last_api_call
        if time_since_last_call < self.min_delay:
            time.sleep(self.min_delay - time_since_last_call)
        self.last_api_call = time.time()

    def get_claude_response(self, prompt: str) -> str:
        """Claude API를 호출하여 응답을 받습니다."""
        self._respect_rate_limit()
        try:
            response = self.claude_client.messages.create(
                model="claude-3-5-haiku-20241022",
                max_tokens=2000,
                temperature=0,
                messages=[
                    {
                        "role": "user",
                        "content": prompt
                    }
                ]
            )
            if isinstance(response.content, list):
                if len(response.content) > 0 and hasattr(response.content[0], 'text'):
                    return response.content[0].text
                return ' '.join(str(item) for item in response.content)
            elif hasattr(response.content, 'text'):
                return response.content.text
            return str(response.content)
        except Exception as e:
            print(f"API 호출 중 오류 발생: {str(e)}")
            raise

    def analyze_student_info(self, text_content: str) -> dict:
        """Claude API를 사용하여 학생 정보를 분석합니다."""
        prompt = f"""
        다음 규칙을 준수하여 작성해주세요.
        다음 텍스트에서 학생 정보를 추출하여 JSON 형식으로 정리해주세요.
        반드시 아래의 JSON 형식만을 사용하여 응답해주세요.
        몇학년때 진행한 것인지 알려주세요.
        
        정리한 내용을 기반으로 직업을 몇개 추천해주시고 그 직업을 추천한 이유를 2줄이내로 작성해주세요
        추천해준 직업에 관련된 학과를 추천해주세요
        추천해준 직업에 관련된 자격증을 추천해주세요
        추천해준 직업에 가지기위해 해야되는 노력을 각각 1줄이상 작성해주세요
        JSON 형식 : 
        {{
            "수상경력": ["특기사항1",
                        "특기사항2", 
                        ...],
            "자격증 및 인증 취득상황": ["진로1",
                                        "진로2", 
                                        ...],
            "진로희망사항": ["진로희망사항1",
                            "진로희망사항2",
                            ...],
            "창의적 체험활동상황": ["창의적 체험활동상황1", 
                                    "창의적 체험활동상황2", 
                                    ...],
            "과목 세부능력 및 특기사항": [
                                    "과목 세부능력 및 특기사항1",
                                    "과목 세부능력 및 특기사항2",
                                    ...],
            "독서활동상황": [
                            "독서활동상황1",
                            "독서활동상황2",
                            ...],
            "행동특성 및 종합의견": [
                                    "행동특성 및 종합의견1",
                                    "행동특성 및 종합의견2",
                                    ...],
            "추천직업": {{
                "추천직업1" : [
                                "추천이유" : ["추천이유"],
                                "직업관련학과" : ["직업관련학과1",
                                                "직업관련학과2", 
                                                ...],
                                "직업관련자격증" : ["직업관련자격증1",
                                                    "직업관련자격증2",
                                                    ...
                                                    ],
                                "노력" : ["노력1",
                                        "노력2",
                                        ...],
                "추천직업2" : [
                                "추천이유" : ["추천이유"],
                                "직업관련학과" : ["직업관련학과1",
                                                "직업관련학과2", 
                                                ...],
                                "직업관련자격증" : ["직업관련자격증1",
                                                    "직업관련자격증2",
                                                    ...
                                                    ],
                                "노력" : ["노력1",
                                        "노력2",
                                        ...],
                ...
            }}
        }}
        
        텍스트 내용:
        {text_content}
        
       
        """

        try:
            response_text = self.get_claude_response(prompt)
            json_start = response_text.find('{')
            json_end = response_text.rfind('}') + 1
            
            if json_start == -1 or json_end == 0:
                raise ValueError("JSON 형식을 찾을 수 없습니다")
                
            json_str = response_text[json_start:json_end]
            info = json.loads(json_str)
            
            if not isinstance(info, dict):
                raise ValueError("잘못된 JSON 구조")
            
            return info
            
        except json.JSONDecodeError as e:
            print(f"JSON 파싱 오류: {str(e)}")
            print(f"응답 텍스트: {response_text}")
            raise
        except Exception as e:
            print(f"정보 분석 중 오류 발생: {str(e)}")
            raise

    def process_pdf(self, pdf_path: str) -> dict:
        """PDF를 처리하고 결과를 저장합니다."""
        try:
            # PDF에서 텍스트 추출
            print("PDF에서 텍스트 추출 중...")
            extracted_text = self.process_large_pdf(pdf_path)
            print("텍스트 추출 완료")

            # Claude API를 사용하여 정보 분석
            print("\n텍스트 분석 중...")
            student_info = self.analyze_student_info(extracted_text)
            
            # 결과 파일 저장
            output_filename = self._generate_filename(os.path.basename(pdf_path))
            output_path = self.output_folder / f"{output_filename}.json"
            
            with open(output_path, 'w', encoding='utf-8') as f:
                json.dump(student_info, f, ensure_ascii=False, indent=2)

            return {
                "status": "success",
                "파일명": os.path.basename(pdf_path),
                "저장경로": str(output_path),
                "추출된_정보": student_info
            }

        except Exception as e:
            return {
                "status": "error",
                "파일명": os.path.basename(pdf_path),
                "오류": str(e)
            }
    def process_pdf1(self, pdf_path: str) -> dict:
        """PDF를 처리하고 결과를 저장합니다."""
        # 텍스트 파일 경로
        file_path1 = "./직업종류.txt"

        # 빈 딕셔너리 생성
        job_dict = {}

        # 파일 읽어서 딕셔너리에 저장
        with open(file_path1, "r", encoding="utf-8") as file:
            for index, line in enumerate(file, start=1):
                job = line.strip()  # 줄바꿈 제거
                job_dict[index] = job

        # JSON 파일 경로
        file_path2 = "./pdf2json/final_extracted_data.json"

        # JSON 파일 읽고 변수에 저장
        with open(file_path2, "r", encoding="utf-8") as file:
            extracted_text = json.load(file)
        
        
        # Claude API를 사용하여 정보 분석
        print("\n텍스트 분석 중...")
        student_info = self.analyze_student_info(extracted_text)
        print("\n결과저장")
        # 결과 파일 저장
        output_filename = self._generate_filename(os.path.basename(pdf_path))
        output_path = self.output_folder / f"{output_filename}.json"
        
        with open(output_path, 'w', encoding='utf-8') as f:
            json.dump(student_info, f, ensure_ascii=False, indent=2)

        return {
            "status": "success",
            "파일명": os.path.basename(pdf_path),
            "저장경로": str(output_path),
            "추출된_정보": student_info
        }

# %%
# 경로 설정
pdf_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\생기부.pdf"
api_key_path = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\claude_api_key.txt"
summary_output_folder = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2summary"

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\User\Documents\GitHub\eduSmile\ai_models\ocr_google_api_key.json"

# PDF 처리 및 분석
processor = PDFProcessor(api_key_path, summary_output_folder)
results = processor.process_pdf(pdf_path)

# 결과 출력
if results["status"] == "success":
    print(f"\n처리 완료: {results['파일명']}")
    print(f"저장 경로: {results['저장경로']}")
    print("\n추출된 정보:")
    print(json.dumps(results['추출된_정보'], ensure_ascii=False, indent=2))
else:
    print(f"\n처리 실패: {results['파일명']}")
    print(f"오류: {results['오류']}")
# Out:
# PDF에서 텍스트 추출 중...
# 모든 데이터를 병합하여 저장했습니다: C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2json\final_extracted_data.json
# 텍스트 추출 완료
#
# 텍스트 분석 중...
#
# 처리 완료: 생기부.pdf
# 저장 경로: C:\Users\User\Documents\GitHub\eduSmile\ai_models\pdf2summary\summary_생기부_20250122_165811.json
#
# 추출된 정보:
# {
#   "수상경력": [
#     "2015학년도 신입생 과제물 최우수(1위)",
#     "근면상(3년정근)"
#   ],
#   "자격증 및 인증 취득상황": [],
#   "진로희망사항": [
#     "1학년: 통계청 공무원",
#     "2학년: 통계청 공무원",
#     "3학년: 보험 계리사, 통계청 공무원"
#   ],
#   "창의적 체험활동상황": [
#     "국토순례문화답사 참여",
#     "체육대회 참여",
#     "덤박골 축제 동아리 부스 운영",
#     "English Festival 참여",
#     "봉사활동 및 진로체험 활동"
#   ],
#   "과목 세부능력 및 특기사항": [
#     "수학, 통계에 대한 깊은 관심",
#     "수학적 원리 이해와 적용 능력",
#     "논리적 사고와 발표 능력"
#   ],
#   "독서활동상황": [
#     "과학, 수학 관련 도서 다수 독서",
#     "진로 관련 도서 독서",
#     "통계 관련 도서 독서"
#   ],
#   "행동특성 및 종합의견": [
#     "목표의식이 뚜렷한 학생",
#     "진로 목표 달성을 위해 노력",
#     "협동심과 봉사정신이 투철",
#     "준법정신과 학업에 대한 열정"
#   ],
#   "추천직업": {
#     "보험 계리사": {
#       "추천이유": [
#         "수학과 통계에 대한 깊은 관심",
#         "데이터 분석 능력과 논리적 사고력 보유"
#       ],
#       "직업관련학과": [
#         "통계학과",
#         "수학과",
#         "보험계리학과"
#       ],
#       "직업관련자격증": [
#         "보험계리사 자격증",
#         "통계분석전문가 자격증",
#         "데이터분석전문가 자격증"
#       ],
#       "노력": [
#         "수학과 통계 관련 심도 있는 학습",
#         "데이터 분석 능력 향상을 위한 지속적인 노력",
#         "관련 전문 서적 및 최신 트렌드 학습"
#       ]
#     },
#     "통계청 공무원": {
#       "추천이유": [
#         "통계와 수학에 대한 뛰어난 이해력",
#         "공공기관에서 데이터 분석에 대한 열정"
#       ],
#       "직업관련학과": [
#         "통계학과",
#         "수학과",
#         "행정학과"
#       ],
#       "직업관련자격증": [
#         "국가통계전문가 자격증",
#         "행정고시",
#         "데이터분석전문가 자격증"
#       ],
#       "노력": [
#         "통계 및 데이터 분석 능력 지속적 개발",
#         "공무원 시험 대비 체계적인 준비",
#         "사회 현상에 대한 폭넓은 이해"
#       ]
#     }
#   }
# }
